# %% [markdown]
# <a href="https://colab.research.google.com/github/Priscilla-c179/python_data-science/blob/main/notebooks/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame({
    "item":['Apple',"Orange","Bananas","watermelon"],
    "Quantity":[12,10,100,3],
    "Price":[1,2,0.5,9],
})

# %%
df
# Out:
#          item  Quantity  Price
# 0       Apple        12    1.0
# 1      Orange        10    2.0
# 2     Bananas       100    0.5
# 3  watermelon         3    9.0

# %%
# get the insight about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   item      4 non-null      object
#  1   Quantity  4 non-null      int64
#  2   Price     4 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 228.0+ bytes

# %%
#get the col
df.columns
# Out:
# Index(['item', 'Quantity', 'Price'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# how many values do you have in df
df.size
# Out:
# 12

# %%
# shape of the dataframe
df.shape
# Out:
# (4, 3)

# %%
df.dtypes
# Out:
# item         object
# Quantity      int64
# Price       float64
# dtype: object

# %% [markdown]
# Accessing

# %%
df['item']
# Out:
# 0         Apple
# 1        Orange
# 2       Bananas
# 3    watermelon
# Name: item, dtype: object

# %%
df['Price']
# Out:
# 0    1.0
# 1    2.0
# 2    0.5
# 3    9.0
# Name: Price, dtype: float64

# %%
df['Quantity']
# Out:
# 0     12
# 1     10
# 2    100
# 3      3
# Name: Quantity, dtype: int64

# %%
df['item'][0]
# Out:
# 'Apple'

# %%
df['Price'][3]
# Out:
# np.float64(9.0)

# %%
#loc is index give row as results
df.loc[0]
# Out:
# item        Apple
# Quantity       12
# Price         1.0
# Name: 0, dtype: object

# %%
df.loc[2]
# Out:
# item        Bananas
# Quantity        100
# Price           0.5
# Name: 2, dtype: object

# %% [markdown]
# Selection

# %%
# get row which price is <5
results=df['Price']<5

# %%
# get the row that price is >5
# filter the specific row
df[df['Price']>5]
# Out:
#          item  Quantity  Price
# 3  watermelon         3    9.0

# %%
df[df['Quantity']<20]
# Out:
#          item  Quantity  Price
# 0       Apple        12    1.0
# 1      Orange        10    2.0
# 3  watermelon         3    9.0

# %%
df[results]
# Out:
#       item  Quantity  Price
# 0    Apple        12    1.0
# 1   Orange        10    2.0
# 2  Bananas       100    0.5

# %% [markdown]
# Adding

# %%
df['Total']=df['Price']*df['Quantity']
df
# Out:
#          item  Quantity  Price  Total
# 0       Apple        12    1.0   12.0
# 1      Orange        10    2.0   20.0
# 2     Bananas       100    0.5   50.0
# 3  watermelon         3    9.0   27.0

# %% [markdown]
# Statistics

# %%
total=df['Total']
total
# Out:
# 0    12.0
# 1    20.0
# 2    50.0
# 3    27.0
# Name: Total, dtype: float64

# %%
total.min(),total.max()
# Out:
# (12.0, 50.0)

# %%
total.mean(),total.std()
# Out:
# (np.float64(27.25), 16.357974609753292)

# %%
total.var()
# Out:
# 267.5833333333333

# %%
total.median()
# Out:
# 23.5

# %%
total.quantile(.25)
# Out:
# np.float64(18.0)

# %%
total.quantile([.25,.50,.75])
# Out:
# 0.25    18.00
# 0.50    23.50
# 0.75    32.75
# Name: Total, dtype: float64

# %%
# get summary full picture of the df as statistics
df.describe()
# Out:
#          Quantity     Price      Total
# count    4.000000  4.000000   4.000000
# mean    31.250000  3.125000  27.250000
# std     45.995471  3.966001  16.357975
# min      3.000000  0.500000  12.000000
# 25%      8.250000  0.875000  18.000000
# 50%     11.000000  1.500000  23.500000
# 75%     34.000000  3.750000  32.750000
# max    100.000000  9.000000  50.000000

# %% [markdown]
# Load from a csv file

# %%
file='/content/sample_data/california_housing_test.csv'
df=pd.read_csv(file)

# %%
# gives the first 5 rows
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...
